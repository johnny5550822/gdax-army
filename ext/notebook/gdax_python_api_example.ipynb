# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# Bring your packages onto the path
import sys, os
sys.path.append(os.path.abspath(os.path.join('..','..')))

from utils import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# parameters
currency = 'LTC-USD'
granularity = '3600'
num_buckets = 24

# import the army library
army = GdaxArmy()
time_, low_, high_, open_, close_, volume_ = army.get_trade_trends(currency=currency, 
                                                                   granularity=granularity, 
                                                                   num_buckets=num_buckets)

# plot
low_.plot()
high_.plot()
open_.plot()
close_.plot()
plt.legend(['low','high','open','close'])
plt.xlabel('hr')
plt.ylabel(currency)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
